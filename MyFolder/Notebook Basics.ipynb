# %%
print("Hello World")

# %%
# %sql
SELECT "Hello World from SQL"

# %% [markdown]
# # Title

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls('/databricks-datasets/')
print(files)

# %%
display(files)
